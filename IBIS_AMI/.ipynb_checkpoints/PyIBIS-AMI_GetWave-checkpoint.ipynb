# %%
import pyibisami.amimodel as ami
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
myModel = ami.AMIModel('sv_ami_ctle_dfe_6_25_ghz_tyco.dll')

# %%
initData = ami.AMIModelInitializer({'root_name' : 'myDLL', 'DFETaps.1' : 1})

# %%
len_imp_response = 256
channel_response = np.zeros((len_imp_response))
channel_response[1]=1
initData.channel_response = channel_response
initData.row_size = len_imp_response
initData.bit_time = 1/6.25e9
initData.sample_interval = 12.5e-12

# %%
myModel.initialize(initData)

# %%
myModel.msg
# Out:
# 'The IBIS-AMI model, sv_ami_ctle_dfe_6_25_ghz_tyco, is unable to initialize the parameter DFETaps.0 from the AMI_Init arguments.  The model will use the default setting. The IBIS-AMI model, sv_ami_ctle_dfe_6_25_ghz_tyco, is unable to initialize the parameter DFETaps.1 from the AMI_Init arguments.  The model will use the default setting. The IBIS-AMI model, sv_ami_ctle_dfe_6_25_ghz_tyco, is unable to initialize the parameter DFETaps.2 from the AMI_Init arguments.  The model will use the default setting. The IBIS-AMI model, sv_ami_ctle_dfe_6_25_ghz_tyco, is unable to initialize the parameter DFETaps.3 from the AMI_Init arguments.  The model will use the default setting. The IBIS-AMI model, sv_ami_ctle_dfe_6_25_ghz_tyco, is unable to initialize the parameter Alpha from the AMI_Init arguments.  The model will use the default setting. '

# %%
h1 = myModel.initOut

# %%
wfm_out = myModel.getWave(h1)

# %%
T = myModel.sample_interval
t = [i * T for i in range(len(h1))]

# %%
plt.plot(t, wfm_out)

# %%
H = np.fft.fft(wfm_out)

# %%
freqs = [i * (1/myModel.sample_interval) / len(t) for i in range(len(t) / 2)]

# %%
plt.plot(freqs, abs(H[:len(H)/2]))

# %%
plt.plot(freqs, np.angle(H[:len(H)/2]))

# %%
plt.semilogx(freqs, 20*np.log10(abs(H[:len(H)/2])))

# %%
myModel.ami_params_in
# Out:
# '(myDLL (VCSEL_Driver_RiseFallTime 10e-12))'
